# %% [markdown]
# # Pandas Practice Workbook — Netflix Dataset (125 Questions)
# **Prepared by Ananda Rimal** · Dataset: `netflix_titles.csv`
#
# **Columns:** `show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description`
#
# **Instructions**
# - Write your answer in the code cell **below each question**
# - Every answer must be pandas code — no manual counting
# - Sections G (GroupBy) and H (Cleaning) may need columns you create along the way — read carefully
#
# | Section | Topic | Questions |
# |---------|-------|-----------|
# | A | First Analysis of Data | 15 |
# | B | Selection with `[]`, `.loc`, `.iloc` | 25 |
# | C | Conditions (with `.loc`) | 20 |
# | D | Sorting | 10 |
# | E | Updating Data | 15 |
# | F | GroupBy | 20 |
# | G | Cleaning | 20 |
# | **Total** | | **125** |

# %% [markdown]
# ## Section A — First Analysis of Data (Q1–Q15)

# %% [markdown]
# #### Q1. Load the dataset into a DataFrame called `df` and display the first 5 rows.

# %%
import pandas as pd
df = pd. read_csv ("/content/netflix_dataset.csv")

# %% [markdown]
# #### Q2. Display the **last 7 rows** of the DataFrame.

# %%
df.tail(7)
# Out:
#      show_id     type                     title      director  \
# 8800   s8801    Movie      Lost Season Revealed  Pablo Sharma
# 8801   s8802    Movie           Our Storm Files    Noah Weber
# 8802   s8803    Movie  Sacred Season Experiment           NaN
# 8803   s8804    Movie    Burning Mirror Project   Omar Petrov
# 8804   s8805  TV Show      Amazing House Rising           NaN
# 8805   s8806    Movie               Sweet Heart  Sarah Miller
# 8806   s8807  TV Show                    A Girl           NaN
#
#                                                    cast  \
# 8800                Chen Cohen, Liam Zhao, Ethan Gurung
# 8801          Ji-hoon Petrov, Ahmed Johnson, Rajesh Kim
# 8802  Sven Bakshi, Meera Petrov, Ananya Brown, Ji-ho...
# 8803                         Bikash Schmidt, Kenji Wang
# 8804  Chen Zhao, Sunita Rahman, Sunita Schmidt, Zara...
# 8805  Rahul Smith, Noah Singh, Sophie Santos, Priya ...
# 8806  Ahmed Murphy, Min-ji Bakshi, Sophie Patel, Nis...
#
#                      country         date_added  release_year rating  \
# 8800                   India  November 19, 2018          2017  TV-MA
# 8801                 Germany     March 17, 2019          2018  TV-14
# 8802                     NaN       May 12, 2019          2018  TV-14
# 8803  Germany, United States   November 5, 2020          2015  TV-14
# 8804                   India        May 1, 2020          2020  TV-MA
# 8805                   India     March 25, 2020          2019     NR
# 8806                  Norway     March 20, 2021          2021  TV-MA
#
#        duration                                          listed_in  \
# 8800    123 min           Classic Movies, Children & Family Movies
# 8801    215 min                                    Romantic Movies
# 8802     54 min  Sports Movies, Faith & Spirituality, Romantic ...
# 8803     41 min                                     Anime Features
# 8804   1 Season               TV Thrillers, International TV Shows
# 8805     46 min    Independent Movies, LGBTQ Movies, Horror Movies
# 8806  2 Seasons      TV Action & Adventure, TV Shows, Anime Series
#
#                                             description
# 8800  On the eve of a wedding, a young journalist le...
# 8801  After a chance encounter, a widowed farmer ris...
# 8802  Torn between duty and desire, a widowed farmer...
# 8803  Torn between duty and desire, a widowed farmer...
# 8804  Torn between duty and desire, an ambitious che...
# 8805  Decades after the war, a struggling musician u...
# 8806  After a chance encounter, an aging film star u...

# %% [markdown]
# #### Q3. How many rows and columns does the dataset have?

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# #### Q4. Display the names of all columns.

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# #### Q5. Use `info()` — which columns have missing values, and what is the data type of each column?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6166 non-null   object
#  4   cast          7954 non-null   object
#  5   country       8038 non-null   object
#  6   date_added    8799 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8799 non-null   object
#  9   duration      8803 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# #### Q6. Use `describe()` on the numeric columns. What is the minimum and maximum `release_year`?

# %%
df.describe() #1925 is the minimum release year while 2021 is the maximum
# Out:
#        release_year
# count    8807.00000
# mean     2012.54116
# std        11.09967
# min      1925.00000
# 25%      2011.00000
# 50%      2016.00000
# 75%      2019.00000
# max      2021.00000

# %% [markdown]
# #### Q7. Use `describe(include="object")` on the text columns. Which value appears most often in the `type` column?

# %%
df.describe(include="object")
# Out:
#        show_id   type                  title     director  \
# count     8807   8807                   8807         6166
# unique    8807      2                   7373         2414
# top      s8807  Movie  Modern Empire Project  Nisha Verma
# freq         1   6035                      7           10
#
#                           cast        country         date_added rating  \
# count                     7954           8038               8799   8799
# unique                    7953            755               3618     17
# top     Ravi Park, Ahmed Rossi  United States  February 11, 2021  TV-MA
# freq                         2           2314                 13   2924
#
#         duration     listed_in  \
# count       8803          8807
# unique       231          3398
# top     1 Season  LGBTQ Movies
# freq        1586           114
#
#                                               description
# count                                                8807
# unique                                               1152
# top     Torn between duty and desire, a teenage prodig...
# freq                                                   17

# %% [markdown]
# #### Q8. Count the missing values in **every** column with one command.

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2641
# cast             853
# country          769
# date_added         8
# release_year       0
# rating             8
# duration           4
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# #### Q9. Which single column has the **most** missing values?

# %%
df.isna().sum().idxmax()
# Out:
# 'director'

# %% [markdown]
# #### Q10. How many **unique** values are in the `rating` column? Display them.

# %%
df["rating"].nunique()
# Out:
# 17

# %%
df["rating"].unique()
# Out:
# array(['R', 'TV-MA', 'TV-14', 'TV-Y', 'TV-Y7', 'TV-PG', 'TV-G', 'PG-13',
#        'PG', 'NR', 'G', 'NC-17', 'TV-Y7-FV', 'UR', nan, '61 min',
#        '62 min', '74 min'], dtype=object)

# %% [markdown]
# #### Q11. Show 5 **random** rows using `sample()`.

# %%
df.sample(5)
# Out:
#      show_id     type                     title      director  \
# 2973   s2974    Movie  Amazing Machine in Paris   Aiko Bakshi
# 1560   s1561    Movie      The Mirror of Mumbai    Zara Novak
# 7561   s7562  TV Show       Lost Escape Diaries           NaN
# 3349   s3350    Movie        The Family Project  Lucia Sharma
# 3451   s3452    Movie    Endless Song Uncovered  Tomasz Silva
#
#                                                    cast        country  \
# 2973  Sven Fernandez, Omar Smith, Sunita Gurung, Kwa...  United States
# 1560  Maria Thapa, Layla Mishra, Sophie Chen, Kwame ...            NaN
# 7561  Aarav Rahman, Chloe Sharma, Pierre Wang, Ji-ho...  United States
# 3349  Bikash Thapa, Rahul Hassan, Tomasz Nguyen, Min...    Philippines
# 3451  Omar Okafor, Chloe Rahman, Emma Rossi, Emma Ta...         Mexico
#
#              date_added  release_year rating  duration  \
# 2973       July 9, 2020          2013  TV-MA    92 min
# 1560  November 19, 2021          2021  TV-PG   171 min
# 7561  December 13, 2016          2016  TV-MA  1 Season
# 3349  November 10, 2018          2009      R    51 min
# 3451      June 22, 2021          2021     PG   194 min
#
#                                               listed_in  \
# 2973     Stand-Up Comedy, Anime Features, Horror Movies
# 1560                                           Comedies
# 7561                          Spanish-Language TV Shows
# 3349  Cult Movies, International Movies, Classic Movies
# 3451  LGBTQ Movies, Thrillers, Children & Family Movies
#
#                                             description
# 2973  Determined to start over, a retired detective ...
# 1560  Decades after the war, a small-town teacher fi...
# 7561  In a small town, a widowed farmer learns that ...
# 3349  In the middle of a heatwave, a small-town teac...
# 3451  Torn between duty and desire, an ambitious che...

# %% [markdown]
# #### Q12. What is the memory usage of the DataFrame? (hint: `info()` or `memory_usage()`)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6166 non-null   object
#  4   cast          7954 non-null   object
#  5   country       8038 non-null   object
#  6   date_added    8799 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8799 non-null   object
#  9   duration      8803 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# #### Q13. Display the data type of only the `release_year` column.

# %%
df["release_year"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### Q14. Count how many titles are of each `type` using `value_counts()`.

# %%
df["type"].value_counts()
# Out:
# type
# Movie      6035
# TV Show    2772
# Name: count, dtype: int64

# %% [markdown]
# #### Q15. Check: does the dataset contain any **fully duplicated** rows?

# %%
df.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# ## Section B — Selection with `[]`, `.loc`, `.iloc` (Q16–Q40)
# *(Q16–Q30: default 0,1,2,... index · Q31–Q40: after `set_index("show_id")`)*

# %% [markdown]
# #### Q16. Select the `title` column as a **Series**.

# %%
df ['title']
# Out:
# 0           Secret Storm Forever
# 1                   Black Forest
# 2               An Legacy Rising
# 3             My Journey Diaries
# 4                    Autumn Love
#                   ...
# 8802    Sacred Season Experiment
# 8803      Burning Mirror Project
# 8804        Amazing House Rising
# 8805                 Sweet Heart
# 8806                      A Girl
# Name: title, Length: 8807, dtype: object

# %%
type(df['title'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Q17. Select the `title` column as a **DataFrame** (hint: double brackets).

# %%
df [['title']]
# Out:
#                          title
# 0         Secret Storm Forever
# 1                 Black Forest
# 2             An Legacy Rising
# 3           My Journey Diaries
# 4                  Autumn Love
# ...                        ...
# 8802  Sacred Season Experiment
# 8803    Burning Mirror Project
# 8804      Amazing House Rising
# 8805               Sweet Heart
# 8806                    A Girl
#
# [8807 rows x 1 columns]

# %%
type(df[["title"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Q18. Select the columns `title`, `type`, and `country` together.

# %%
df[['title','type','country']]
# Out:
#                          title     type                 country
# 0         Secret Storm Forever    Movie                     NaN
# 1                 Black Forest    Movie                    Peru
# 2             An Legacy Rising  TV Show                   India
# 3           My Journey Diaries    Movie       Indonesia, France
# 4                  Autumn Love    Movie          United Kingdom
# ...                        ...      ...                     ...
# 8802  Sacred Season Experiment    Movie                     NaN
# 8803    Burning Mirror Project    Movie  Germany, United States
# 8804      Amazing House Rising  TV Show                   India
# 8805               Sweet Heart    Movie                   India
# 8806                    A Girl  TV Show                  Norway
#
# [8807 rows x 3 columns]

# %% [markdown]
# #### Q19. Select the first 10 rows using `.iloc`.

# %%
df.iloc[0:10]
# Out:
#   show_id     type                   title         director  \
# 0      s1    Movie    Secret Storm Forever    Marcus Garcia
# 1      s2    Movie            Black Forest      Ethan Silva
# 2      s3  TV Show        An Legacy Rising      James Rossi
# 3      s4    Movie      My Journey Diaries    Bikash Okafor
# 4      s5    Movie             Autumn Love  Priya Fernandez
# 5      s6  TV Show   The Island Chronicles              NaN
# 6      s7    Movie   Red Detective Forever       Ravi Verma
# 7      s8    Movie            Modern Night     Nisha Sharma
# 8      s9  TV Show   Dark Promise in Paris              NaN
# 9     s10  TV Show  Rising Forest Part Two      Ethan Cohen
#
#                                                 cast            country  \
# 0  Daniel Andersen, Olivia Mishra, Chen Hassan, S...                NaN
# 1         Min-ji Bakshi, Hassan Sharma, Rajesh Baral               Peru
# 2              Maria Verma, Lucia Tanaka, Omar Novak              India
# 3           Chen Reyes, Sunita Adhikari, Maria Novak  Indonesia, France
# 4  Aiko Yamamoto, Nisha Bakshi, Sven Wang, Tomasz...     United Kingdom
# 5                        Ananya Miller, Omar Johnson     United Kingdom
# 6  Ravi Hassan, Daniel Reyes, Olivia Mendez, Marc...      United States
# 7          Sunita Park, Sophie Brown, Layla Yamamoto              India
# 8  Ingrid Tanaka, Priya Zhao, Aiko Novak, Kwame S...             Mexico
# 9  Priya Dubois, Sophie Nguyen, Noah Kowalski, Sa...      United States
#
#            date_added  release_year rating  duration  \
# 0      March 27, 2019          2013      R   182 min
# 1      March 19, 2011          2011  TV-MA   114 min
# 2        May 19, 2015          2013  TV-MA  1 Season
# 3  September 12, 2021          2021  TV-14   122 min
# 4         May 2, 2020          2015      R    93 min
# 5       March 7, 2020          2019   TV-Y  1 Season
# 6    January 14, 2017          2017  TV-14   243 min
# 7   February 18, 2021          2012  TV-14    59 min
# 8  September 26, 2018          2015  TV-Y7  1 Season
# 9    November 8, 2016          2015  TV-MA  1 Season
#
#                                            listed_in  \
# 0                    Sci-Fi & Fantasy, Horror Movies
# 1  Children & Family Movies, Documentaries, Indep...
# 2  TV Mysteries, International TV Shows, Anime Se...
# 3                                    Romantic Movies
# 4                                             Movies
# 5                                          TV Horror
# 6                          Classic Movies, Thrillers
# 7  Sci-Fi & Fantasy, Anime Features, Action & Adv...
# 8                             TV Mysteries, Kids' TV
# 9      TV Horror, Teen TV Shows, Science & Nature TV
#
#                                          description
# 0  After a chance encounter, a group of college f...
# 1  Determined to start over, a widowed farmer rac...
# 2  In the middle of a heatwave, an ambitious chef...
# 3  Decades after the war, a retired detective mus...
# 4  Torn between duty and desire, a ruthless busin...
# 5  Torn between duty and desire, an ambitious che...
# 6  Determined to start over, a group of college f...
# 7  Facing financial ruin, two estranged siblings ...
# 8  Haunted by the past, an aging film star sets o...
# 9  On the eve of a wedding, a rookie police offic...

# %% [markdown]
# #### Q20. Select rows with labels 10 to 20 using `.loc`. How many rows do you get and why?

# %%
df.loc [10:20]
# Out:
#    show_id     type                    title          director  \
# 10     s11  TV Show           Hidden Journey    Noah Fernandez
# 11     s12  TV Show   Amazing King of Mumbai      Rahul Mendez
# 12     s13  TV Show             Black Legacy               NaN
# 13     s14  TV Show       My Hunter Part Two               NaN
# 14     s15    Movie   Sacred Game Experiment     Rajesh Sharma
# 15     s16    Movie          A Song in Paris     Kenji Schmidt
# 16     s17  TV Show      Last Machine Reborn               NaN
# 17     s18    Movie       A Story Chronicles  Valentina Santos
# 18     s19    Movie            Hidden Escape     Bikash Nguyen
# 19     s20    Movie  White Secret Experiment    Camille Murphy
# 20     s21    Movie     Silent Secret Affair      Elena Sharma
#
#                                                  cast                 country  \
# 10       Ahmed Adhikari, Min-ji Hassan, Tomasz Mendez                  Canada
# 11               Sven Novak, Maria Cohen, Kenji Reyes           United States
# 12                       Isabella Schmidt, Liam Brown           United States
# 13  Tomasz Silva, Nisha Petrov, Rahul Fernandez, M...           United States
# 14  Pierre Costa, Chen Reyes, Priya Miller, Nisha ...             Switzerland
# 15  Rajesh Iyer, Wei Adhikari, Tomasz Rossi, Min-j...           United States
# 16  Rajesh Dubois, Sven Cohen, Valentina Kowalski,...                   Spain
# 17  Bikash Silva, Aarav Schmidt, James Ibrahim, Ra...               Australia
# 18  Liam Smith, Marcus Chen, Ahmed Singh, Hassan L...  Germany, United States
# 19                                                NaN                     NaN
# 20  Camille Dubois, Isabella Okafor, Arjun Bakshi,...           United States
#
#             date_added  release_year rating   duration  \
# 10   December 21, 2015          2009  TV-14  4 Seasons
# 11    January 23, 2019          2019  TV-PG  8 Seasons
# 12       April 5, 2012          1989  TV-MA   1 Season
# 13    February 6, 2019          2018  TV-MA   1 Season
# 14    February 5, 2021          2008  TV-MA     43 min
# 15       July 17, 2013          2009  TV-PG    138 min
# 16    January 14, 2021          2020  TV-MA  6 Seasons
# 17  September 17, 2019          2018   TV-G     63 min
# 18     August 27, 2016          2008  PG-13     74 min
# 19   November 11, 2019          2017  TV-14     47 min
# 20    October 14, 2014          1999  TV-MA     80 min
#
#                                             listed_in  \
# 10  International TV Shows, TV Action & Adventure,...
# 11                                       TV Thrillers
# 12                                    Korean TV Shows
# 13                                   British TV Shows
# 14                                       LGBTQ Movies
# 15              Faith & Spirituality, Romantic Movies
# 16                                       TV Mysteries
# 17                                    Romantic Movies
# 18   Action & Adventure, Cult Movies, Stand-Up Comedy
# 19      Stand-Up Comedy, Action & Adventure, Comedies
# 20                           Children & Family Movies
#
#                                           description
# 10  During a nationwide blackout, a teenage prodig...
# 11  On the eve of a wedding, a young journalist le...
# 12  Following a mysterious disappearance, a ruthle...
# 13  Haunted by the past, a teenage prodigy builds ...
# 14  Torn between duty and desire, a widowed farmer...
# 15  In a small town, a retired detective races aga...
# 16  In the middle of a heatwave, a young journalis...
# 17  On the eve of a wedding, a struggling musician...
# 18  During a nationwide blackout, a struggling mus...
# 19  On the eve of a wedding, a young journalist se...
# 20  Torn between duty and desire, an aging film st...

# %% [markdown]
# #### Q21. Using `.iloc`, select rows at positions 5 to 14 (10 rows). Compare with Q20 — why is the row count logic different?

# %%
df.iloc [5:14]
# Out:
#    show_id     type                   title        director  \
# 5       s6  TV Show   The Island Chronicles             NaN
# 6       s7    Movie   Red Detective Forever      Ravi Verma
# 7       s8    Movie            Modern Night    Nisha Sharma
# 8       s9  TV Show   Dark Promise in Paris             NaN
# 9      s10  TV Show  Rising Forest Part Two     Ethan Cohen
# 10     s11  TV Show          Hidden Journey  Noah Fernandez
# 11     s12  TV Show  Amazing King of Mumbai    Rahul Mendez
# 12     s13  TV Show            Black Legacy             NaN
# 13     s14  TV Show      My Hunter Part Two             NaN
#
#                                                  cast         country  \
# 5                         Ananya Miller, Omar Johnson  United Kingdom
# 6   Ravi Hassan, Daniel Reyes, Olivia Mendez, Marc...   United States
# 7           Sunita Park, Sophie Brown, Layla Yamamoto           India
# 8   Ingrid Tanaka, Priya Zhao, Aiko Novak, Kwame S...          Mexico
# 9   Priya Dubois, Sophie Nguyen, Noah Kowalski, Sa...   United States
# 10       Ahmed Adhikari, Min-ji Hassan, Tomasz Mendez          Canada
# 11               Sven Novak, Maria Cohen, Kenji Reyes   United States
# 12                       Isabella Schmidt, Liam Brown   United States
# 13  Tomasz Silva, Nisha Petrov, Rahul Fernandez, M...   United States
#
#             date_added  release_year rating   duration  \
# 5        March 7, 2020          2019   TV-Y   1 Season
# 6     January 14, 2017          2017  TV-14    243 min
# 7    February 18, 2021          2012  TV-14     59 min
# 8   September 26, 2018          2015  TV-Y7   1 Season
# 9     November 8, 2016          2015  TV-MA   1 Season
# 10   December 21, 2015          2009  TV-14  4 Seasons
# 11    January 23, 2019          2019  TV-PG  8 Seasons
# 12       April 5, 2012          1989  TV-MA   1 Season
# 13    February 6, 2019          2018  TV-MA   1 Season
#
#                                             listed_in  \
# 5                                           TV Horror
# 6                           Classic Movies, Thrillers
# 7   Sci-Fi & Fantasy, Anime Features, Action & Adv...
# 8                              TV Mysteries, Kids' TV
# 9       TV Horror, Teen TV Shows, Science & Nature TV
# 10  International TV Shows, TV Action & Adventure,...
# 11                                       TV Thrillers
# 12                                    Korean TV Shows
# 13                                   British TV Shows
#
#                                           description
# 5   Torn between duty and desire, an ambitious che...
# 6   Determined to start over, a group of college f...
# 7   Facing financial ruin, two estranged siblings ...
# 8   Haunted by the past, an aging film star sets o...
# 9   On the eve of a wedding, a rookie police offic...
# 10  During a nationwide blackout, a teenage prodig...
# 11  On the eve of a wedding, a young journalist le...
# 12  Following a mysterious disappearance, a ruthle...
# 13  Haunted by the past, a teenage prodigy builds ...

# %% [markdown]
# #### Q22. Using `.loc`, select rows 0 to 9 with only the columns `title` and `release_year`.

# %%
df.loc [0:9, ["title",'release_year']]
# Out:
#                     title  release_year
# 0    Secret Storm Forever          2013
# 1            Black Forest          2011
# 2        An Legacy Rising          2013
# 3      My Journey Diaries          2021
# 4             Autumn Love          2015
# 5   The Island Chronicles          2019
# 6   Red Detective Forever          2017
# 7            Modern Night          2012
# 8   Dark Promise in Paris          2015
# 9  Rising Forest Part Two          2015

# %% [markdown]
# #### Q23. Using `.iloc`, select the first 8 rows and the first 5 columns.

# %%
df.iloc [0:8 , 0:5]
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Secret Storm Forever    Marcus Garcia
# 1      s2    Movie           Black Forest      Ethan Silva
# 2      s3  TV Show       An Legacy Rising      James Rossi
# 3      s4    Movie     My Journey Diaries    Bikash Okafor
# 4      s5    Movie            Autumn Love  Priya Fernandez
# 5      s6  TV Show  The Island Chronicles              NaN
# 6      s7    Movie  Red Detective Forever       Ravi Verma
# 7      s8    Movie           Modern Night     Nisha Sharma
#
#                                                 cast
# 0  Daniel Andersen, Olivia Mishra, Chen Hassan, S...
# 1         Min-ji Bakshi, Hassan Sharma, Rajesh Baral
# 2              Maria Verma, Lucia Tanaka, Omar Novak
# 3           Chen Reyes, Sunita Adhikari, Maria Novak
# 4  Aiko Yamamoto, Nisha Bakshi, Sven Wang, Tomasz...
# 5                        Ananya Miller, Omar Johnson
# 6  Ravi Hassan, Daniel Reyes, Olivia Mendez, Marc...
# 7          Sunita Park, Sophie Brown, Layla Yamamoto

# %% [markdown]
# #### Q24. Using `.iloc`, select the **last row** of the DataFrame.

# %%
df.iloc[[-1]]
# Out:
#      show_id     type   title director  \
# 8806   s8807  TV Show  A Girl      NaN
#
#                                                    cast country  \
# 8806  Ahmed Murphy, Min-ji Bakshi, Sophie Patel, Nis...  Norway
#
#           date_added  release_year rating   duration  \
# 8806  March 20, 2021          2021  TV-MA  2 Seasons
#
#                                           listed_in  \
# 8806  TV Action & Adventure, TV Shows, Anime Series
#
#                                             description
# 8806  After a chance encounter, an aging film star u...

# %% [markdown]
# #### Q25. Using `.iloc`, select the last 5 rows and the last 2 columns (negative positions).

# %%
df.iloc[-5:, -2:]
# Out:
#                                               listed_in  \
# 8802  Sports Movies, Faith & Spirituality, Romantic ...
# 8803                                     Anime Features
# 8804               TV Thrillers, International TV Shows
# 8805    Independent Movies, LGBTQ Movies, Horror Movies
# 8806      TV Action & Adventure, TV Shows, Anime Series
#
#                                             description
# 8802  Torn between duty and desire, a widowed farmer...
# 8803  Torn between duty and desire, a widowed farmer...
# 8804  Torn between duty and desire, an ambitious che...
# 8805  Decades after the war, a struggling musician u...
# 8806  After a chance encounter, an aging film star u...

# %% [markdown]
# #### Q26. Using `.loc`, get the value of `title` for the row with label 50.

# %%
df.loc [50 , "title"]
# Out:
# 'Black Legacy Diaries'

# %% [markdown]
# #### Q27. Using `.iloc`, get the value in row position 100, column position 2. Which column is that?

# %%
df.iloc [99, 1]
# Out:
# 'Movie'

# %% [markdown]
# #### Q28. Using `.iloc`, select every 100th row (hint: slicing with a step `::100`).

# %%
df.iloc[::100,:]
# Out:
#      show_id     type                          title       director  \
# 0         s1    Movie           Secret Storm Forever  Marcus Garcia
# 100     s101    Movie            Last Game Uncovered  Min-ji Garcia
# 200     s201    Movie                  Golden Empire         Wei Li
# 300     s301  TV Show          An River of Kathmandu            NaN
# 400     s401    Movie            Quiet Promise Files   Diego Bakshi
# ...      ...      ...                            ...            ...
# 8400   s8401    Movie                    Sacred Chef     Zara Verma
# 8500   s8501  TV Show                  Little Escape   Rahul Torres
# 8600   s8601  TV Show  Broken Detective of Kathmandu            NaN
# 8700   s8701    Movie            Quiet Story Forever            NaN
# 8800   s8801    Movie           Lost Season Revealed   Pablo Sharma
#
#                                                    cast               country  \
# 0     Daniel Andersen, Olivia Mishra, Chen Hassan, S...                   NaN
# 100   Hiroshi Petrov, Bikash Rossi, Pablo Kowalski, ...  India, United States
# 200   Ahmed Khan, Priya Patel, Elena Petrov, Liam Sh...              Thailand
# 300   Priya Adhikari, Zara Dubois, Kenji Cohen, Pabl...        United Kingdom
# 400   Elena Lee, Emma Torres, Camille Silva, Meera B...           South Korea
# ...                                                 ...                   ...
# 8400  Olivia Lee, Bikash Mendez, Sunita Johnson, Jam...         United States
# 8500  Ji-hoon Murphy, Ethan Silva, Aarav Patel, Zara...         United States
# 8600                        Chloe Okafor, Isabella Zhao                 Spain
# 8700                       Lucia Ibrahim, Anna Yamamoto         France, Japan
# 8800                Chen Cohen, Liam Zhao, Ethan Gurung                 India
#
#               date_added  release_year rating   duration  \
# 0         March 27, 2019          2013      R    182 min
# 100     November 5, 2017          2015  TV-MA     53 min
# 200     October 18, 2017          2016  TV-14    237 min
# 300       March 16, 2016          2008  TV-14   1 Season
# 400   September 28, 2014          2009  TV-MA     61 min
# ...                  ...           ...    ...        ...
# 8400        July 9, 2021          2017  TV-14    111 min
# 8500         May 8, 2021          2020  TV-14  2 Seasons
# 8600     August 13, 2011          2010  TV-MA   1 Season
# 8700   December 15, 2020          2019  TV-MA    253 min
# 8800   November 19, 2018          2017  TV-MA    123 min
#
#                                             listed_in  \
# 0                     Sci-Fi & Fantasy, Horror Movies
# 100             Romantic Movies, LGBTQ Movies, Dramas
# 200                          Music & Musicals, Dramas
# 300            Docuseries, TV Horror, Korean TV Shows
# 400   International Movies, Stand-Up Comedy, Comedies
# ...                                               ...
# 8400                             Faith & Spirituality
# 8500      TV Sci-Fi & Fantasy, International TV Shows
# 8600                    TV Thrillers, Korean TV Shows
# 8700                             International Movies
# 8800         Classic Movies, Children & Family Movies
#
#                                             description
# 0     After a chance encounter, a group of college f...
# 100   In a small town, a small-town teacher learns t...
# 200   Torn between duty and desire, a small-town tea...
# 300   Following a mysterious disappearance, an aging...
# 400   When tragedy strikes, an ambitious chef races ...
# ...                                                 ...
# 8400  Torn between duty and desire, a struggling mus...
# 8500  In a small town, a struggling musician races a...
# 8600  Determined to start over, an aging film star r...
# 8700  Facing financial ruin, a ruthless businesswoma...
# 8800  On the eve of a wedding, a young journalist le...
#
# [89 rows x 12 columns]

# %% [markdown]
# #### Q29. Using `.loc`, select rows 0 to 4 and **all** columns from `title` to `country` (label slicing on columns!).

# %%
df.loc[0:4, 'title':'country']
# Out:
#                   title         director  \
# 0  Secret Storm Forever    Marcus Garcia
# 1          Black Forest      Ethan Silva
# 2      An Legacy Rising      James Rossi
# 3    My Journey Diaries    Bikash Okafor
# 4           Autumn Love  Priya Fernandez
#
#                                                 cast            country
# 0  Daniel Andersen, Olivia Mishra, Chen Hassan, S...                NaN
# 1         Min-ji Bakshi, Hassan Sharma, Rajesh Baral               Peru
# 2              Maria Verma, Lucia Tanaka, Omar Novak              India
# 3           Chen Reyes, Sunita Adhikari, Maria Novak  Indonesia, France
# 4  Aiko Yamamoto, Nisha Bakshi, Sven Wang, Tomasz...     United Kingdom

# %% [markdown]
# #### Q30. Select three specific rows by label — 3, 33, and 333 — in one `.loc` call.

# %%
df.loc[[3,33,333]]
# Out:
#     show_id     type                     title       director  \
# 3        s4    Movie        My Journey Diaries  Bikash Okafor
# 33      s34    Movie   Winter Journey Part Two    Chloe Verma
# 333    s334  TV Show  Falling Kingdom Part Two            NaN
#
#                                                   cast            country  \
# 3             Chen Reyes, Sunita Adhikari, Maria Novak  Indonesia, France
# 33                                                 NaN   Argentina, Spain
# 333  Lucas Garcia, Amara Zhao, Valentina Dubois, Ra...      United States
#
#              date_added  release_year rating   duration  \
# 3    September 12, 2021          2021  TV-14    122 min
# 33         July 8, 2011          2006  TV-MA    221 min
# 333   September 7, 2019          2015  TV-MA  3 Seasons
#
#                                       listed_in  \
# 3                               Romantic Movies
# 33                                Horror Movies
# 333  Romantic TV Shows, TV Horror, TV Mysteries
#
#                                            description
# 3    Decades after the war, a retired detective mus...
# 33   In the middle of a heatwave, a teenage prodigy...
# 333  Facing financial ruin, a teenage prodigy uncov...

# %% [markdown]
# #### Q31. Set `show_id` as the index of `df` (keep it for the rest of Section B). Display the head.

# %%
df = pd.read_csv('/content/netflix_dataset.csv')
df = df.set_index('show_id')
df.head()
# Out:
#             type                 title         director  \
# show_id
# s1         Movie  Secret Storm Forever    Marcus Garcia
# s2         Movie          Black Forest      Ethan Silva
# s3       TV Show      An Legacy Rising      James Rossi
# s4         Movie    My Journey Diaries    Bikash Okafor
# s5         Movie           Autumn Love  Priya Fernandez
#
#                                                       cast            country  \
# show_id
# s1       Daniel Andersen, Olivia Mishra, Chen Hassan, S...                NaN
# s2              Min-ji Bakshi, Hassan Sharma, Rajesh Baral               Peru
# s3                   Maria Verma, Lucia Tanaka, Omar Novak              India
# s4                Chen Reyes, Sunita Adhikari, Maria Novak  Indonesia, France
# s5       Aiko Yamamoto, Nisha Bakshi, Sven Wang, Tomasz...     United Kingdom
#
#                  date_added  release_year rating  duration  \
# show_id
# s1           March 27, 2019          2013      R   182 min
# s2           March 19, 2011          2011  TV-MA   114 min
# s3             May 19, 2015          2013  TV-MA  1 Season
# s4       September 12, 2021          2021  TV-14   122 min
# s5              May 2, 2020          2015      R    93 min
#
#                                                  listed_in  \
# show_id
# s1                         Sci-Fi & Fantasy, Horror Movies
# s2       Children & Family Movies, Documentaries, Indep...
# s3       TV Mysteries, International TV Shows, Anime Se...
# s4                                         Romantic Movies
# s5                                                  Movies
#
#                                                description
# show_id
# s1       After a chance encounter, a group of college f...
# s2       Determined to start over, a widowed farmer rac...
# s3       In the middle of a heatwave, an ambitious chef...
# s4       Decades after the war, a retired detective mus...
# s5       Torn between duty and desire, a ruthless busin...

# %% [markdown]
# #### Q32. Using `.loc`, select the row with label `"s1"`.

# %%
df.loc ['s1']
# Out:
# type                                                        Movie
# title                                        Secret Storm Forever
# director                                            Marcus Garcia
# cast            Daniel Andersen, Olivia Mishra, Chen Hassan, S...
# country                                                       NaN
# date_added                                         March 27, 2019
# release_year                                                 2013
# rating                                                          R
# duration                                                  182 min
# listed_in                         Sci-Fi & Fantasy, Horror Movies
# description     After a chance encounter, a group of college f...
# Name: s1, dtype: object

# %% [markdown]
# #### Q33. Using `.loc`, select rows `"s10"` to `"s15"`. Does label slicing still include the end?

# %%
df.loc [['s10', 's11']]
# Out:
#             type                   title        director  \
# show_id
# s10      TV Show  Rising Forest Part Two     Ethan Cohen
# s11      TV Show          Hidden Journey  Noah Fernandez
#
#                                                       cast        country  \
# show_id
# s10      Priya Dubois, Sophie Nguyen, Noah Kowalski, Sa...  United States
# s11           Ahmed Adhikari, Min-ji Hassan, Tomasz Mendez         Canada
#
#                 date_added  release_year rating   duration  \
# show_id
# s10       November 8, 2016          2015  TV-MA   1 Season
# s11      December 21, 2015          2009  TV-14  4 Seasons
#
#                                                  listed_in  \
# show_id
# s10          TV Horror, Teen TV Shows, Science & Nature TV
# s11      International TV Shows, TV Action & Adventure,...
#
#                                                description
# show_id
# s10      On the eve of a wedding, a rookie police offic...
# s11      During a nationwide blackout, a teenage prodig...

# %% [markdown]
# #### Q34. Using `.iloc`, select the row at position 0. Is it the same row as label `"s1"`?

# %%
df.iloc [0]
# Out:
# index                                                           0
# show_id                                                        s1
# type                                                        Movie
# title                                        Secret Storm Forever
# director                                            Marcus Garcia
# cast            Daniel Andersen, Olivia Mishra, Chen Hassan, S...
# country                                                       NaN
# date_added                                         March 27, 2019
# release_year                                                 2013
# rating                                                          R
# duration                                                  182 min
# listed_in                         Sci-Fi & Fantasy, Horror Movies
# description     After a chance encounter, a group of college f...
# Name: 0, dtype: object

# %% [markdown]
# #### Q35. Using `.loc`, get the `title` and `type` of the show with id `"s500"`.

# %%
df.loc ['s500', ['title','type']]
# Out:
# title    Autumn Ghost Project
# type                  TV Show
# Name: s500, dtype: object

# %% [markdown]
# #### Q36. Using `.iloc`, select the row at position 499. Is its label `"s500"`? Explain why or why not in a comment.

# %%
df.iloc [499]   #The label is always one more than the position,
# because one counter started at 0 and the other started at 1. So position 499 lands on s500.
# Out:
# type                                                      TV Show
# title                                        Autumn Ghost Project
# director                                                      NaN
# cast            Aarav Mishra, Ji-hoon Miller, Fatima Tanaka, O...
# country                                                     Spain
# date_added                                      December 25, 2012
# release_year                                                 2000
# rating                                                      TV-14
# duration                                                2 Seasons
# listed_in                                         Korean TV Shows
# description     Facing financial ruin, two estranged siblings ...
# Name: s500, dtype: object

# %% [markdown]
# #### Q37. Using `.loc`, select shows `"s1"`, `"s100"`, and `"s1000"` with columns `title` and `release_year`.

# %%
df.loc [["s1","s100","s1000"], ["title",'release_year']]
# Out:
#                            title  release_year
# show_id
# s1          Secret Storm Forever          2013
# s100     Rising Mirror Uncovered          2020
# s1000         My Forest Part Two          2015

# %% [markdown]
# #### Q38. What happens if you run `df.loc[0]` now? Try it, read the error, and explain in a comment.

# %%
df.loc[0]    #we have set show_id as index so loc asks the label so 0 makes no sense.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_649/232408830.py in <cell line: 0>()
# ----> 1 df.loc[0]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1429         # fall thru to straight lookup
#    1430         self._validate_key(key, axis)
# -> 1431         return self._get_label(key, axis=axis)
#    1432
#    1433     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1379     def _get_label(self, label, axis: AxisInt):
#    1380         # GH#5567 this will fail if the label is not present in the axis.
# -> 1381         return self.obj.xs(label, axis=axis)
#    1382
#    1383     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4299                     new_index = index[loc]
#    4300         else:
# -> 4301             loc = index.get_loc(key)
#    4302
#    4303             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %% [markdown]
# #### Q39. Using `.iloc`, select rows at positions [0, 99, 999] in one call.

# %%
df.iloc [["0","99","999"]]
# Out:
#           type                    title       director  \
# show_id
# s1       Movie     Secret Storm Forever  Marcus Garcia
# s100     Movie  Rising Mirror Uncovered   James Petrov
# s1000    Movie       My Forest Part Two   Aarav Gurung
#
#                                                       cast  \
# show_id
# s1       Daniel Andersen, Olivia Mishra, Chen Hassan, S...
# s100     Sophie Chen, Olivia Mishra, Elena Zhao, Priya ...
# s1000               Ahmed Torres, Ethan Singh, Aiko Tanaka
#
#                         country        date_added  release_year rating  \
# show_id
# s1                          NaN    March 27, 2019          2013      R
# s100     United States, Germany    April 16, 2021          2020  PG-13
# s1000             United States  October 21, 2021          2015      R
#
#         duration                                          listed_in  \
# show_id
# s1       182 min                    Sci-Fi & Fantasy, Horror Movies
# s100     197 min  International Movies, Action & Adventure, Cult...
# s1000    136 min                        Classic Movies, Cult Movies
#
#                                                description
# show_id
# s1       After a chance encounter, a group of college f...
# s100     On the eve of a wedding, a struggling musician...
# s1000    Decades after the war, a rookie police officer...

# %% [markdown]
# #### Q40. Reset the index back to 0,1,2,... using `reset_index()`. Display the head.

# %%
df = df.reset_index()
df.head()
# Out:
#    index show_id     type                 title         director  \
# 0      0      s1    Movie  Secret Storm Forever    Marcus Garcia
# 1      1      s2    Movie          Black Forest      Ethan Silva
# 2      2      s3  TV Show      An Legacy Rising      James Rossi
# 3      3      s4    Movie    My Journey Diaries    Bikash Okafor
# 4      4      s5    Movie           Autumn Love  Priya Fernandez
#
#                                                 cast            country  \
# 0  Daniel Andersen, Olivia Mishra, Chen Hassan, S...                NaN
# 1         Min-ji Bakshi, Hassan Sharma, Rajesh Baral               Peru
# 2              Maria Verma, Lucia Tanaka, Omar Novak              India
# 3           Chen Reyes, Sunita Adhikari, Maria Novak  Indonesia, France
# 4  Aiko Yamamoto, Nisha Bakshi, Sven Wang, Tomasz...     United Kingdom
#
#            date_added  release_year rating  duration  \
# 0      March 27, 2019          2013      R   182 min
# 1      March 19, 2011          2011  TV-MA   114 min
# 2        May 19, 2015          2013  TV-MA  1 Season
# 3  September 12, 2021          2021  TV-14   122 min
# 4         May 2, 2020          2015      R    93 min
#
#                                            listed_in  \
# 0                    Sci-Fi & Fantasy, Horror Movies
# 1  Children & Family Movies, Documentaries, Indep...
# 2  TV Mysteries, International TV Shows, Anime Se...
# 3                                    Romantic Movies
# 4                                             Movies
#
#                                          description
# 0  After a chance encounter, a group of college f...
# 1  Determined to start over, a widowed farmer rac...
# 2  In the middle of a heatwave, an ambitious chef...
# 3  Decades after the war, a retired detective mus...
# 4  Torn between duty and desire, a ruthless busin...

# %% [markdown]
# ## Section C — Conditions with `.loc` (Q41–Q60)
# *Write every filter with `df.loc[condition]` or `df.loc[condition, columns]` style where possible.*

# %% [markdown]
# #### Q41. Select all rows where `type` is `"Movie"`.

# %%
import pandas as pd
df = pd. read_csv ("/content/netflix_dataset.csv")

# %%
df.loc[df["type"] == "Movie"]
# Out:
#      show_id   type                     title         director  \
# 0         s1  Movie      Secret Storm Forever    Marcus Garcia
# 1         s2  Movie              Black Forest      Ethan Silva
# 3         s4  Movie        My Journey Diaries    Bikash Okafor
# 4         s5  Movie               Autumn Love  Priya Fernandez
# 6         s7  Movie     Red Detective Forever       Ravi Verma
# ...      ...    ...                       ...              ...
# 8800   s8801  Movie      Lost Season Revealed     Pablo Sharma
# 8801   s8802  Movie           Our Storm Files       Noah Weber
# 8802   s8803  Movie  Sacred Season Experiment              NaN
# 8803   s8804  Movie    Burning Mirror Project      Omar Petrov
# 8805   s8806  Movie               Sweet Heart     Sarah Miller
#
#                                                    cast  \
# 0     Daniel Andersen, Olivia Mishra, Chen Hassan, S...
# 1            Min-ji Bakshi, Hassan Sharma, Rajesh Baral
# 3              Chen Reyes, Sunita Adhikari, Maria Novak
# 4     Aiko Yamamoto, Nisha Bakshi, Sven Wang, Tomasz...
# 6     Ravi Hassan, Daniel Reyes, Olivia Mendez, Marc...
# ...                                                 ...
# 8800                Chen Cohen, Liam Zhao, Ethan Gurung
# 8801          Ji-hoon Petrov, Ahmed Johnson, Rajesh Kim
# 8802  Sven Bakshi, Meera Petrov, Ananya Brown, Ji-ho...
# 8803                         Bikash Schmidt, Kenji Wang
# 8805  Rahul Smith, Noah Singh, Sophie Santos, Priya ...
#
#                      country          date_added  release_year rating  \
# 0                        NaN      March 27, 2019          2013      R
# 1                       Peru      March 19, 2011          2011  TV-MA
# 3          Indonesia, France  September 12, 2021          2021  TV-14
# 4             United Kingdom         May 2, 2020          2015      R
# 6              United States    January 14, 2017          2017  TV-14
# ...                      ...                 ...           ...    ...
# 8800                   India   November 19, 2018          2017  TV-MA
# 8801                 Germany      March 17, 2019          2018  TV-14
# 8802                     NaN        May 12, 2019          2018  TV-14
# 8803  Germany, United States    November 5, 2020          2015  TV-14
# 8805                   India      March 25, 2020          2019     NR
#
#      duration                                          listed_in  \
# 0     182 min                    Sci-Fi & Fantasy, Horror Movies
# 1     114 min  Children & Family Movies, Documentaries, Indep...
# 3     122 min                                    Romantic Movies
# 4      93 min                                             Movies
# 6     243 min                          Classic Movies, Thrillers
# ...       ...                                                ...
# 8800  123 min           Classic Movies, Children & Family Movies
# 8801  215 min                                    Romantic Movies
# 8802   54 min  Sports Movies, Faith & Spirituality, Romantic ...
# 8803   41 min                                     Anime Features
# 8805   46 min    Independent Movies, LGBTQ Movies, Horror Movies
#
#                                             description
# 0     After a chance encounter, a group of college f...
# 1     Determined to start over, a widowed farmer rac...
# 3     Decades after the war, a retired detective mus...
# 4     Torn between duty and desire, a ruthless busin...
# 6     Determined to start over, a group of college f...
# ...                                                 ...
# 8800  On the eve of a wedding, a young journalist le...
# 8801  After a chance encounter, a widowed farmer ris...
# 8802  Torn between duty and desire, a widowed farmer...
# 8803  Torn between duty and desire, a widowed farmer...
# 8805  Decades after the war, a struggling musician u...
#
# [6035 rows x 12 columns]

# %% [markdown]
# #### Q42. Select all rows where `type` is `"TV Show"` — show only `title` and `country` using one `.loc` call.

# %%
df.loc[df["type"]=="TV Show",["title","country"]]
# Out:
#                         title         country
# 2            An Legacy Rising           India
# 5       The Island Chronicles  United Kingdom
# 8       Dark Promise in Paris          Mexico
# 9      Rising Forest Part Two   United States
# 10             Hidden Journey          Canada
# ...                       ...             ...
# 8796       Red Escape Diaries             NaN
# 8797  Bitter Kingdom Part Two           China
# 8799              Broken Road   United States
# 8804     Amazing House Rising           India
# 8806                   A Girl          Norway
#
# [2772 rows x 2 columns]

# %% [markdown]
# #### Q43. Select all titles released in 2021.

# %%
df.loc[df["release_year"] == 2021, ["title"]]
# Out:
#                            title
# 3             My Journey Diaries
# 27                        My War
# 30                 Hidden Letter
# 43          Quiet Doctor Forever
# 52      Endless Journey of Seoul
# ...                          ...
# 8777                 Bitter Girl
# 8787  Frozen Murder of Kathmandu
# 8797     Bitter Kingdom Part Two
# 8798       Secret Island Project
# 8806                      A Girl
#
# [809 rows x 1 columns]

# %% [markdown]
# #### Q44. Select all titles released **before** 2000.

# %%
df.loc[df["release_year"] < 2000, ["title"]]
# Out:
#                        title
# 12              Black Legacy
# 20      Silent Secret Affair
# 38      The Forest Uncovered
# 45        Last Forest Rising
# 48      Rising Song of Seoul
# ...                      ...
# 8749     Last Season Project
# 8760          Burning Mirror
# 8765      Last Doctor Reborn
# 8774   Silent Murder Returns
# 8785  Winter Garden Part Two
#
# [794 rows x 1 columns]

# %% [markdown]
# #### Q45. Select all titles released between 2015 and 2020 (inclusive) — two conditions with `&`.

# %%
df.loc[(df["release_year"] >= 2015) & (df["release_year"] <= 2020), ["title"]]
# Out:
#                          title
# 4                  Autumn Love
# 5        The Island Chronicles
# 6        Red Detective Forever
# 8        Dark Promise in Paris
# 9       Rising Forest Part Two
# ...                        ...
# 8801           Our Storm Files
# 8802  Sacred Season Experiment
# 8803    Burning Mirror Project
# 8804      Amazing House Rising
# 8805               Sweet Heart
#
# [4670 rows x 1 columns]

# %% [markdown]
# #### Q46. Select all Movies released after 2019 (two conditions).

# %%
df.loc[(df["release_year"] > 2019) & (df["type"] == "Movie"), ["title"]]
# Out:
#                            title
# 3             My Journey Diaries
# 27                        My War
# 43          Quiet Doctor Forever
# 61       Our Murder of Kathmandu
# 65                 A Love Secret
# ...                          ...
# 8776      Dark Garden Chronicles
# 8777                 Bitter Girl
# 8787  Frozen Murder of Kathmandu
# 8792          Love Song of Seoul
# 8798       Secret Island Project
#
# [1116 rows x 1 columns]

# %% [markdown]
# #### Q47. Select all titles where `rating` is `"TV-MA"`.

# %%
df.loc[df["rating"]=="TV-MA", ["title"]]
# Out:
#                        title
# 1               Black Forest
# 2           An Legacy Rising
# 9     Rising Forest Part Two
# 12              Black Legacy
# 13        My Hunter Part Two
# ...                      ...
# 8795       Red Legacy Affair
# 8796      Red Escape Diaries
# 8800    Lost Season Revealed
# 8804    Amazing House Rising
# 8806                  A Girl
#
# [2924 rows x 1 columns]

# %% [markdown]
# #### Q48. Select all titles where `rating` is either `"PG"` or `"PG-13"` using `.isin()`.

# %%
df.loc[df["rating"].isin(["PG","PG-13"]), ["title"]]
# Out:
#                         title
# 18              Hidden Escape
# 24       Ancient Heart Affair
# 36       Broken Song of Seoul
# 43       Quiet Doctor Forever
# 68    Eternal Kingdom Returns
# ...                       ...
# 8740    Rising Garden Project
# 8760           Burning Mirror
# 8775    Rising Heart Part Two
# 8776   Dark Garden Chronicles
# 8784   Rising Night Uncovered
#
# [909 rows x 1 columns]

# %% [markdown]
# #### Q49. Select all titles where `rating` is **NOT** `"TV-MA"` (hint: `~` or `!=`).

# %%
df.loc[df["rating"] != "TV-MA", ["title"]]
# Out:
#                          title
# 0         Secret Storm Forever
# 3           My Journey Diaries
# 4                  Autumn Love
# 5        The Island Chronicles
# 6        Red Detective Forever
# ...                        ...
# 8799               Broken Road
# 8801           Our Storm Files
# 8802  Sacred Season Experiment
# 8803    Burning Mirror Project
# 8805               Sweet Heart
#
# [5883 rows x 1 columns]

# %% [markdown]
# #### Q50. Select all titles where `country` is exactly `"India"`.

# %%
df.loc [df["country"]=="India", ["title"]]
# Out:
#                        title
# 2           An Legacy Rising
# 7               Modern Night
# 22    Quiet River Experiment
# 72     Awesome Queen Diaries
# 114    Amazing Empire Rising
# ...                      ...
# 8764   Black Mirror of Seoul
# 8778  Silent Machine Returns
# 8800    Lost Season Revealed
# 8804    Amazing House Rising
# 8805             Sweet Heart
#
# [843 rows x 1 columns]

# %% [markdown]
# #### Q51. Select all titles where `country` **contains** `"India"` (hint: `str.contains`, use `na=False`). Why is the row count different from the previous question?

# %%
df.loc[df["country"].str.contains ("India", na=False) , ["title"]]
# Out:
#                        title
# 2           An Legacy Rising
# 7               Modern Night
# 22    Quiet River Experiment
# 30             Hidden Letter
# 34       Love Machine Reborn
# ...                      ...
# 8775   Rising Heart Part Two
# 8778  Silent Machine Returns
# 8800    Lost Season Revealed
# 8804    Amazing House Rising
# 8805             Sweet Heart
#
# [1225 rows x 1 columns]

# %% [markdown]
# #### Q52. Select all Movies from the United States — show only `title` and `release_year`.

# %%
df.loc[df["type"]=="Movie", ["title","release_year"]]
# Out:
#                          title  release_year
# 0         Secret Storm Forever          2013
# 1                 Black Forest          2011
# 3           My Journey Diaries          2021
# 4                  Autumn Love          2015
# 6        Red Detective Forever          2017
# ...                        ...           ...
# 8800      Lost Season Revealed          2017
# 8801           Our Storm Files          2018
# 8802  Sacred Season Experiment          2018
# 8803    Burning Mirror Project          2015
# 8805               Sweet Heart          2019
#
# [6035 rows x 2 columns]

# %% [markdown]
# #### Q53. Select all titles where `director` is missing (hint: `isna()`).

# %%
df.loc[df["director"].isna(), ["title"]]
# Out:
#                          title
# 5        The Island Chronicles
# 8        Dark Promise in Paris
# 12                Black Legacy
# 13          My Hunter Part Two
# 16         Last Machine Reborn
# ...                        ...
# 8797   Bitter Kingdom Part Two
# 8799               Broken Road
# 8802  Sacred Season Experiment
# 8804      Amazing House Rising
# 8806                    A Girl
#
# [2641 rows x 1 columns]

# %%
df.head(10)
# Out:
#   show_id     type                   title         director  \
# 0      s1    Movie    Secret Storm Forever    Marcus Garcia
# 1      s2    Movie            Black Forest      Ethan Silva
# 2      s3  TV Show        An Legacy Rising      James Rossi
# 3      s4    Movie      My Journey Diaries    Bikash Okafor
# 4      s5    Movie             Autumn Love  Priya Fernandez
# 5      s6  TV Show   The Island Chronicles              NaN
# 6      s7    Movie   Red Detective Forever       Ravi Verma
# 7      s8    Movie            Modern Night     Nisha Sharma
# 8      s9  TV Show   Dark Promise in Paris              NaN
# 9     s10  TV Show  Rising Forest Part Two      Ethan Cohen
#
#                                                 cast            country  \
# 0  Daniel Andersen, Olivia Mishra, Chen Hassan, S...                NaN
# 1         Min-ji Bakshi, Hassan Sharma, Rajesh Baral               Peru
# 2              Maria Verma, Lucia Tanaka, Omar Novak              India
# 3           Chen Reyes, Sunita Adhikari, Maria Novak  Indonesia, France
# 4  Aiko Yamamoto, Nisha Bakshi, Sven Wang, Tomasz...     United Kingdom
# 5                        Ananya Miller, Omar Johnson     United Kingdom
# 6  Ravi Hassan, Daniel Reyes, Olivia Mendez, Marc...      United States
# 7          Sunita Park, Sophie Brown, Layla Yamamoto              India
# 8  Ingrid Tanaka, Priya Zhao, Aiko Novak, Kwame S...             Mexico
# 9  Priya Dubois, Sophie Nguyen, Noah Kowalski, Sa...      United States
#
#            date_added  release_year rating  duration  \
# 0      March 27, 2019          2013      R   182 min
# 1      March 19, 2011          2011  TV-MA   114 min
# 2        May 19, 2015          2013  TV-MA  1 Season
# 3  September 12, 2021          2021  TV-14   122 min
# 4         May 2, 2020          2015      R    93 min
# 5       March 7, 2020          2019   TV-Y  1 Season
# 6    January 14, 2017          2017  TV-14   243 min
# 7   February 18, 2021          2012  TV-14    59 min
# 8  September 26, 2018          2015  TV-Y7  1 Season
# 9    November 8, 2016          2015  TV-MA  1 Season
#
#                                            listed_in  \
# 0                    Sci-Fi & Fantasy, Horror Movies
# 1  Children & Family Movies, Documentaries, Indep...
# 2  TV Mysteries, International TV Shows, Anime Se...
# 3                                    Romantic Movies
# 4                                             Movies
# 5                                          TV Horror
# 6                          Classic Movies, Thrillers
# 7  Sci-Fi & Fantasy, Anime Features, Action & Adv...
# 8                             TV Mysteries, Kids' TV
# 9      TV Horror, Teen TV Shows, Science & Nature TV
#
#                                          description
# 0  After a chance encounter, a group of college f...
# 1  Determined to start over, a widowed farmer rac...
# 2  In the middle of a heatwave, an ambitious chef...
# 3  Decades after the war, a retired detective mus...
# 4  Torn between duty and desire, a ruthless busin...
# 5  Torn between duty and desire, an ambitious che...
# 6  Determined to start over, a group of college f...
# 7  Facing financial ruin, two estranged siblings ...
# 8  Haunted by the past, an aging film star sets o...
# 9  On the eve of a wedding, a rookie police offic...

# %% [markdown]
# #### Q54. Select all titles where `director` is **not** missing.

# %%
df.loc[df["director"].notna(), ["title"] ]
# Out:
#                        title
# 0       Secret Storm Forever
# 1               Black Forest
# 2           An Legacy Rising
# 3         My Journey Diaries
# 4                Autumn Love
# ...                      ...
# 8798   Secret Island Project
# 8800    Lost Season Revealed
# 8801         Our Storm Files
# 8803  Burning Mirror Project
# 8805             Sweet Heart
#
# [6166 rows x 1 columns]

# %% [markdown]
# #### Q55. Select all TV Shows released in 2020 **or** 2021.

# %%
df.loc[(df["type"]=="TV Show") & (df["release_year"].isin([2020,2021])), ["title"]]
# Out:
#                          title
# 16         Last Machine Reborn
# 28           Wild Heart Rising
# 30               Hidden Letter
# 52    Endless Journey of Seoul
# 60        Awesome City Returns
# ...                        ...
# 8764     Black Mirror of Seoul
# 8773     Wild War of Kathmandu
# 8797   Bitter Kingdom Part Two
# 8804      Amazing House Rising
# 8806                    A Girl
#
# [501 rows x 1 columns]

# %% [markdown]
# #### Q56. Select all titles whose `title` starts with the letter `"A"` (hint: `str.startswith`, `na=False`).

# %%
df.loc[df["title"].str.startswith("A", na=False), ["title"]]
# Out:
#                        title
# 2           An Legacy Rising
# 4                Autumn Love
# 11    Amazing King of Mumbai
# 15           A Song in Paris
# 17        A Story Chronicles
# ...                      ...
# 8772     Autumn Heart Affair
# 8779   Amazing Season Reborn
# 8788    A Night of Kathmandu
# 8804    Amazing House Rising
# 8806                  A Girl
#
# [1395 rows x 1 columns]

# %% [markdown]
# #### Q57. Select all titles whose `title` contains the word `"Love"`.

# %%
df.loc[df["title"].str.contains("Love",na=False),["title"] ]
# Out:
#                       title
# 4               Autumn Love
# 34      Love Machine Reborn
# 65            A Love Secret
# 90        Love City Forever
# 118   Love Doctor of Mumbai
# ...                     ...
# 8724      Love City Project
# 8732            Love Doctor
# 8733    Love Machine Rising
# 8752  Love Hunter Uncovered
# 8792     Love Song of Seoul
#
# [481 rows x 1 columns]

# %% [markdown]
# #### Q58. Using `.loc` with a condition, show the `title`, `rating`, and `release_year` of all Movies rated `"R"`.

# %%
df.loc[df["rating"]=="R", ["title","rating","release_year"]]
# Out:
#                          title rating  release_year
# 0         Secret Storm Forever      R          2013
# 4                  Autumn Love      R          2015
# 26         Great Queen Project      R          2015
# 27                      My War      R          2021
# 37                Quiet Family      R          2001
# ...                        ...    ...           ...
# 8723  Falling Hunter Uncovered      R          2010
# 8724         Love City Project      R          2018
# 8759         The Island Reborn      R          2020
# 8761    Great Forest of Mumbai      R          2010
# 8769  Modern Machine of Mumbai      R          2016
#
# [911 rows x 3 columns]

# %% [markdown]
# #### Q59. Count how many Movies were released after 2015 (condition + `len()` or `.shape`).

# %%
df.loc[(df["type"]=="Movie") & (df["release_year"] > 2015)].shape[0]
# Out:
# 3224

# %% [markdown]
# #### Q60. Challenge: select all Movies that are from India **or** Nepal and released after 2010 — careful with brackets around the `|` condition!

# %%
df.loc[(df["type"]=="Movie") & (df["country"].isin(["India","Nepal"])),["title"]]
# Out:
#                          title
# 7                 Modern Night
# 25       Ancient Legacy Reborn
# 130            Midnight Family
# 172      Amazing Murder Reborn
# 177       Golden Song in Paris
# ...                        ...
# 8722  Hidden Garden Experiment
# 8741        Last Chef in Paris
# 8778    Silent Machine Returns
# 8800      Lost Season Revealed
# 8805               Sweet Heart
#
# [626 rows x 1 columns]

# %% [markdown]
# ## Section D — Sorting (Q61–Q70)

# %% [markdown]
# #### Q61. Sort the DataFrame by `release_year` ascending. Show the head — what are the oldest titles?

# %%
df.sort_values("release_year", ascending= True)
# Out:
#      show_id     type                     title          director  \
# 6879   s6880    Movie     Ancient Road Part Two      Min-ji Silva
# 4921   s4922    Movie    Autumn Doctor in Paris  Valentina Tanaka
# 2024   s2025  TV Show     The Chef of Kathmandu               NaN
# 4237   s4238  TV Show  Midnight Hunter Part Two               NaN
# 3938   s3939    Movie     Dark Murder Uncovered     Carlos Mishra
# ...      ...      ...                       ...               ...
# 8777   s8778    Movie               Bitter Girl       Nina Murphy
# 30       s31  TV Show             Hidden Letter               NaN
# 27       s28    Movie                    My War      Tomasz Weber
# 8806   s8807  TV Show                    A Girl               NaN
# 3         s4    Movie        My Journey Diaries     Bikash Okafor
#
#                                                    cast  \
# 6879  Bikash Bakshi, Elena Murphy, Nisha Reyes, Bika...
# 4921                           Meera Petrov, Aiko Smith
# 2024                                                NaN
# 4237                     Yuki Fernandez, Aiko Fernandez
# 3938  Emma Khan, Isabella Davies, Chloe Bakshi, Aiko...
# ...                                                 ...
# 8777  Yuki Iyer, Camille Dubois, Bikash Okafor, Isab...
# 30    Min-ji Petrov, Lucas Li, Yuki Sharma, Yuki Web...
# 27    Layla Patel, Wei Li, Nina Nguyen, Olivia Duboi...
# 8806  Ahmed Murphy, Min-ji Bakshi, Sophie Patel, Nis...
# 3              Chen Reyes, Sunita Adhikari, Maria Novak
#
#                           country          date_added  release_year rating  \
# 6879  South Africa, United States     January 3, 2014          1925  TV-MA
# 4921                United States   December 22, 2018          1925  TV-MA
# 2024                  South Korea   September 3, 2010          1925   TV-Y
# 4237                       Canada    February 8, 2012          1925  TV-14
# 3938                        Japan  September 24, 2019          1926  TV-PG
# ...                           ...                 ...           ...    ...
# 8777                          NaN     January 7, 2021          2021  TV-MA
# 30           United States, India       June 19, 2021          2021  TV-MA
# 27                  United States       March 7, 2021          2021      R
# 8806                       Norway      March 20, 2021          2021  TV-MA
# 3               Indonesia, France  September 12, 2021          2021  TV-14
#
#        duration                                      listed_in  \
# 6879     50 min                       Thrillers, Sports Movies
# 4921     96 min                            Cult Movies, Dramas
# 2024   1 Season                      Spanish-Language TV Shows
# 4237   1 Season                                       TV Shows
# 3938     51 min                            Cult Movies, Dramas
# ...         ...                                            ...
# 8777     52 min   Cult Movies, Documentaries, Sci-Fi & Fantasy
# 30     1 Season                              Romantic TV Shows
# 27       75 min                               Sci-Fi & Fantasy
# 8806  2 Seasons  TV Action & Adventure, TV Shows, Anime Series
# 3       122 min                                Romantic Movies
#
#                                             description
# 6879  During a nationwide blackout, a rookie police ...
# 4921  Determined to start over, a teenage prodigy se...
# 2024  Facing financial ruin, two estranged siblings ...
# 4237  In the middle of a heatwave, a rookie police o...
# 3938  Haunted by the past, a small-town teacher must...
# ...                                                 ...
# 8777  Following a mysterious disappearance, a small-...
# 30    In a small town, a ruthless businesswoman must...
# 27    Decades after the war, a rookie police officer...
# 8806  After a chance encounter, an aging film star u...
# 3     Decades after the war, a retired detective mus...
#
# [8807 rows x 12 columns]

# %% [markdown]
# #### Q62. Sort by `release_year` **descending**. Show the 10 newest titles.

# %%
df.sort_values ("release_year", ascending=False)
# Out:
#      show_id     type                      title          director  \
# 8777   s8778    Movie                Bitter Girl       Nina Murphy
# 27       s28    Movie                     My War      Tomasz Weber
# 8798   s8799    Movie      Secret Island Project       Omar Petrov
# 8797   s8798  TV Show    Bitter Kingdom Part Two               NaN
# 43       s44    Movie       Quiet Doctor Forever       Nina Gurung
# ...      ...      ...                        ...               ...
# 5274   s5275    Movie  Silent Machine Experiment   Min-ji Yamamoto
# 6879   s6880    Movie      Ancient Road Part Two      Min-ji Silva
# 4921   s4922    Movie     Autumn Doctor in Paris  Valentina Tanaka
# 4237   s4238  TV Show   Midnight Hunter Part Two               NaN
# 2024   s2025  TV Show      The Chef of Kathmandu               NaN
#
#                                                    cast  \
# 8777  Yuki Iyer, Camille Dubois, Bikash Okafor, Isab...
# 27    Layla Patel, Wei Li, Nina Nguyen, Olivia Duboi...
# 8798  Sunita Murphy, Pablo Mishra, Amara Yamamoto, N...
# 8797                                                NaN
# 43                  Priya Brown, Maria Chen, Ravi Thapa
# ...                                                 ...
# 5274  Liam Weber, Bikash Rossi, Aiko Ali, Marcus Has...
# 6879  Bikash Bakshi, Elena Murphy, Nisha Reyes, Bika...
# 4921                           Meera Petrov, Aiko Smith
# 4237                     Yuki Fernandez, Aiko Fernandez
# 2024                                                NaN
#
#                           country         date_added  release_year rating  \
# 8777                          NaN    January 7, 2021          2021  TV-MA
# 27                  United States      March 7, 2021          2021      R
# 8798                          NaN  November 28, 2021          2021  TV-PG
# 8797                        China   November 5, 2021          2021  TV-14
# 43                  United States    January 8, 2021          2021     PG
# ...                           ...                ...           ...    ...
# 5274                        India      July 13, 2017          1926  TV-MA
# 6879  South Africa, United States    January 3, 2014          1925  TV-MA
# 4921                United States  December 22, 2018          1925  TV-MA
# 4237                       Canada   February 8, 2012          1925  TV-14
# 2024                  South Korea  September 3, 2010          1925   TV-Y
#
#       duration                                     listed_in  \
# 8777    52 min  Cult Movies, Documentaries, Sci-Fi & Fantasy
# 27      75 min                              Sci-Fi & Fantasy
# 8798   104 min                          Faith & Spirituality
# 8797  1 Season                     Kids' TV, Korean TV Shows
# 43     203 min           Romantic Movies, Action & Adventure
# ...        ...                                           ...
# 5274   196 min                                        Dramas
# 6879    50 min                      Thrillers, Sports Movies
# 4921    96 min                           Cult Movies, Dramas
# 4237  1 Season                                      TV Shows
# 2024  1 Season                     Spanish-Language TV Shows
#
#                                             description
# 8777  Following a mysterious disappearance, a small-...
# 27    Decades after the war, a rookie police officer...
# 8798  Decades after the war, a small-town teacher bu...
# 8797  Determined to start over, a small-town teacher...
# 43    Haunted by the past, an ambitious chef finds l...
# ...                                                 ...
# 5274  Haunted by the past, an ambitious chef builds ...
# 6879  During a nationwide blackout, a rookie police ...
# 4921  Determined to start over, a teenage prodigy se...
# 4237  In the middle of a heatwave, a rookie police o...
# 2024  Facing financial ruin, two estranged siblings ...
#
# [8807 rows x 12 columns]

# %% [markdown]
# #### Q63. Sort by `title` alphabetically.

# %%
df.sort_values ("title", ascending=True)
# Out:
#      show_id     type                     title        director  \
# 1004   s1005  TV Show                     A Boy             NaN
# 3798   s3799    Movie                     A Boy   Rajesh Mishra
# 3363   s3364    Movie          A Boy Chronicles      Ethan Chen
# 5751   s5752    Movie             A Boy Diaries             NaN
# 2484   s2485    Movie             A Boy Diaries  Sarah Yamamoto
# ...      ...      ...                       ...             ...
# 4606   s4607  TV Show        Winter War Returns             NaN
# 8419   s8420  TV Show            Winter Wedding             NaN
# 4000   s4001  TV Show    Winter Wedding Forever             NaN
# 8753   s8754    Movie    Winter Wedding Returns       Nina Wang
# 6834   s6835  TV Show  Winter Wedding Uncovered   Bikash Rahman
#
#                                                    cast         country  \
# 1004  Diego Murphy, Chloe Hassan, Ravi Verma, Anna L...   United States
# 3798  Pierre Verma, Ravi Weber, Liam Tanaka, Lucia W...  United Kingdom
# 3363  Priya Mishra, Omar Miller, Nisha Chen, Tomasz ...             NaN
# 5751                          Valentina Kim, Pablo Zhao             NaN
# 2484  Carlos Ibrahim, Bikash Kim, Ji-hoon Schmidt, W...           India
# ...                                                 ...             ...
# 4606                                                NaN             NaN
# 8419  Yuki Petrov, Amara Andersen, Ingrid Li, Min-ji...           Egypt
# 4000  Yuki Thapa, Rajesh Yamamoto, Aarav Baral, Aara...             NaN
# 8753                                                NaN         Germany
# 6834  Nina Fernandez, Chen Silva, Sunita Silva, Vale...       Indonesia
#
#              date_added  release_year rating   duration  \
# 1004     August 6, 2011          2004  TV-PG  6 Seasons
# 3798   December 3, 2017          2016     PG     54 min
# 3363    August 10, 2019          1991  TV-14    174 min
# 5751  December 10, 2016          2016  PG-13    216 min
# 2484      June 12, 2019          2018     PG     82 min
# ...                 ...           ...    ...        ...
# 4606   December 1, 2021          2019  TV-MA   1 Season
# 8419        May 1, 2020          2020  TV-MA   1 Season
# 4000   October 13, 2013          2009  TV-14   1 Season
# 8753      March 7, 2021          2021  TV-14     53 min
# 6834    August 12, 2020          2019  TV-14  2 Seasons
#
#                                               listed_in  \
# 1004                  Crime TV Shows, Romantic TV Shows
# 3798  Comedies, Children & Family Movies, Sci-Fi & F...
# 3363                                          Thrillers
# 5751                                           Comedies
# 2484                      Documentaries, Classic Movies
# ...                                                 ...
# 4606                             International TV Shows
# 8419                  Docuseries, TV Comedies, TV Shows
# 4000                                       Anime Series
# 8753                  Stand-Up Comedy, Sci-Fi & Fantasy
# 6834  International TV Shows, Spanish-Language TV Shows
#
#                                             description
# 1004  In the middle of a heatwave, a ruthless busine...
# 3798  In the middle of a heatwave, a rookie police o...
# 3363  In a small town, a group of college friends fi...
# 5751  During a nationwide blackout, an ambitious che...
# 2484  In the middle of a heatwave, two estranged sib...
# ...                                                 ...
# 4606  Decades after the war, a struggling musician u...
# 8419  In a small town, a ruthless businesswoman risk...
# 4000  Haunted by the past, a struggling musician mus...
# 8753  When tragedy strikes, a ruthless businesswoman...
# 6834  In a small town, a widowed farmer sets out on ...
#
# [8807 rows x 12 columns]

# %% [markdown]
# #### Q64. Sort by `release_year` descending AND `title` ascending at the same time (list of columns + list of ascending values).

# %%
df.sort_values (["release_year","title"],
                ascending=[False,True])
# Out:
#      show_id     type                      title          director  \
# 8509   s8510  TV Show            A Day Uncovered               NaN
# 8239   s8240    Movie            A Day of Mumbai    Ahmed Adhikari
# 4867   s4868    Movie       A Detective in Paris      Lucas Santos
# 5072   s5073    Movie          A Family Part Two      Chloe Davies
# 6824   s6825    Movie                   A Garden       Ravi Nguyen
# ...      ...      ...                        ...               ...
# 5274   s5275    Movie  Silent Machine Experiment   Min-ji Yamamoto
# 6879   s6880    Movie      Ancient Road Part Two      Min-ji Silva
# 4921   s4922    Movie     Autumn Doctor in Paris  Valentina Tanaka
# 4237   s4238  TV Show   Midnight Hunter Part Two               NaN
# 2024   s2025  TV Show      The Chef of Kathmandu               NaN
#
#                                                    cast  \
# 8509  Noah Brown, Pablo Miller, Daniel Nguyen, Camil...
# 8239  Maria Miller, Liam Kim, Nisha Ali, Nisha Baksh...
# 4867  Elena Zhao, Ravi Wang, Diego Johnson, Aarav Jo...
# 5072                                                NaN
# 6824             Olivia Mendez, Lucia Lee, Layla Gurung
# ...                                                 ...
# 5274  Liam Weber, Bikash Rossi, Aiko Ali, Marcus Has...
# 6879  Bikash Bakshi, Elena Murphy, Nisha Reyes, Bika...
# 4921                           Meera Petrov, Aiko Smith
# 4237                     Yuki Fernandez, Aiko Fernandez
# 2024                                                NaN
#
#                           country         date_added  release_year rating  \
# 8509                        India       May 27, 2021          2021  TV-14
# 8239                United States   February 1, 2021          2021  TV-MA
# 4867                United States   January 28, 2021          2021  PG-13
# 5072     Australia, United States        May 5, 2021          2021  TV-14
# 6824                  South Korea     August 1, 2021          2021  PG-13
# ...                           ...                ...           ...    ...
# 5274                        India      July 13, 2017          1926  TV-MA
# 6879  South Africa, United States    January 3, 2014          1925  TV-MA
# 4921                United States  December 22, 2018          1925  TV-MA
# 4237                       Canada   February 8, 2012          1925  TV-14
# 2024                  South Korea  September 3, 2010          1925   TV-Y
#
#        duration                                     listed_in  \
# 8509  2 Seasons                          Docuseries, Kids' TV
# 8239    220 min           Independent Movies, Romantic Movies
# 4867     56 min                          Faith & Spirituality
# 5072    212 min                        Anime Features, Movies
# 6824     56 min  Comedies, Anime Features, Action & Adventure
# ...         ...                                           ...
# 5274    196 min                                        Dramas
# 6879     50 min                      Thrillers, Sports Movies
# 4921     96 min                           Cult Movies, Dramas
# 4237   1 Season                                      TV Shows
# 2024   1 Season                     Spanish-Language TV Shows
#
#                                             description
# 8509  During a nationwide blackout, an aging film st...
# 8239  Haunted by the past, a struggling musician rac...
# 4867  When tragedy strikes, a rookie police officer ...
# 5072  In the middle of a heatwave, an aging film sta...
# 6824  After a chance encounter, a ruthless businessw...
# ...                                                 ...
# 5274  Haunted by the past, an ambitious chef builds ...
# 6879  During a nationwide blackout, a rookie police ...
# 4921  Determined to start over, a teenage prodigy se...
# 4237  In the middle of a heatwave, a rookie police o...
# 2024  Facing financial ruin, two estranged siblings ...
#
# [8807 rows x 12 columns]

# %% [markdown]
# #### Q65. Sort by `rating`, and show only `title` and `rating` in the result.

# %%
df.sort_values("rating")[["title", "rating"]]
# Out:
#                         title  rating
# 2708               Dark Heart  61 min
# 3415              Last Empire  62 min
# 6614         Hidden Detective  62 min
# 4652      Love Garden Returns  74 min
# 6819   Blue Letter Experiment       G
# ...                       ...     ...
# 3530      A King of Kathmandu     NaN
# 3738  Strange Season Part Two     NaN
# 5163      Rising Night Rising     NaN
# 5687    Modern Doctor Forever     NaN
# 6936  Eternal Dream of Mumbai     NaN
#
# [8807 rows x 2 columns]

# %% [markdown]
# #### Q66. Sort the **index** using `sort_index()` (useful after filtering).

# %%
df.sort_index()
# Out:
#      show_id     type                     title         director  \
# 0         s1    Movie      Secret Storm Forever    Marcus Garcia
# 1         s2    Movie              Black Forest      Ethan Silva
# 2         s3  TV Show          An Legacy Rising      James Rossi
# 3         s4    Movie        My Journey Diaries    Bikash Okafor
# 4         s5    Movie               Autumn Love  Priya Fernandez
# ...      ...      ...                       ...              ...
# 8802   s8803    Movie  Sacred Season Experiment              NaN
# 8803   s8804    Movie    Burning Mirror Project      Omar Petrov
# 8804   s8805  TV Show      Amazing House Rising              NaN
# 8805   s8806    Movie               Sweet Heart     Sarah Miller
# 8806   s8807  TV Show                    A Girl              NaN
#
#                                                    cast  \
# 0     Daniel Andersen, Olivia Mishra, Chen Hassan, S...
# 1            Min-ji Bakshi, Hassan Sharma, Rajesh Baral
# 2                 Maria Verma, Lucia Tanaka, Omar Novak
# 3              Chen Reyes, Sunita Adhikari, Maria Novak
# 4     Aiko Yamamoto, Nisha Bakshi, Sven Wang, Tomasz...
# ...                                                 ...
# 8802  Sven Bakshi, Meera Petrov, Ananya Brown, Ji-ho...
# 8803                         Bikash Schmidt, Kenji Wang
# 8804  Chen Zhao, Sunita Rahman, Sunita Schmidt, Zara...
# 8805  Rahul Smith, Noah Singh, Sophie Santos, Priya ...
# 8806  Ahmed Murphy, Min-ji Bakshi, Sophie Patel, Nis...
#
#                      country          date_added  release_year rating  \
# 0                        NaN      March 27, 2019          2013      R
# 1                       Peru      March 19, 2011          2011  TV-MA
# 2                      India        May 19, 2015          2013  TV-MA
# 3          Indonesia, France  September 12, 2021          2021  TV-14
# 4             United Kingdom         May 2, 2020          2015      R
# ...                      ...                 ...           ...    ...
# 8802                     NaN        May 12, 2019          2018  TV-14
# 8803  Germany, United States    November 5, 2020          2015  TV-14
# 8804                   India         May 1, 2020          2020  TV-MA
# 8805                   India      March 25, 2020          2019     NR
# 8806                  Norway      March 20, 2021          2021  TV-MA
#
#        duration                                          listed_in  \
# 0       182 min                    Sci-Fi & Fantasy, Horror Movies
# 1       114 min  Children & Family Movies, Documentaries, Indep...
# 2      1 Season  TV Mysteries, International TV Shows, Anime Se...
# 3       122 min                                    Romantic Movies
# 4        93 min                                             Movies
# ...         ...                                                ...
# 8802     54 min  Sports Movies, Faith & Spirituality, Romantic ...
# 8803     41 min                                     Anime Features
# 8804   1 Season               TV Thrillers, International TV Shows
# 8805     46 min    Independent Movies, LGBTQ Movies, Horror Movies
# 8806  2 Seasons      TV Action & Adventure, TV Shows, Anime Series
#
#                                             description
# 0     After a chance encounter, a group of college f...
# 1     Determined to start over, a widowed farmer rac...
# 2     In the middle of a heatwave, an ambitious chef...
# 3     Decades after the war, a retired detective mus...
# 4     Torn between duty and desire, a ruthless busin...
# ...                                                 ...
# 8802  Torn between duty and desire, a widowed farmer...
# 8803  Torn between duty and desire, a widowed farmer...
# 8804  Torn between duty and desire, an ambitious che...
# 8805  Decades after the war, a struggling musician u...
# 8806  After a chance encounter, an aging film star u...
#
# [8807 rows x 12 columns]

# %% [markdown]
# #### Q67. Show the 5 oldest Movies (filter first, then sort, then head).

# %%
df.loc[df["type"] == "Movie"].sort_values("release_year").head(5)
# Out:
#      show_id   type                      title          director  \
# 4921   s4922  Movie     Autumn Doctor in Paris  Valentina Tanaka
# 6879   s6880  Movie      Ancient Road Part Two      Min-ji Silva
# 3938   s3939  Movie      Dark Murder Uncovered     Carlos Mishra
# 3361   s3362  Movie     Sacred Family Revealed               NaN
# 5274   s5275  Movie  Silent Machine Experiment   Min-ji Yamamoto
#
#                                                    cast  \
# 4921                           Meera Petrov, Aiko Smith
# 6879  Bikash Bakshi, Elena Murphy, Nisha Reyes, Bika...
# 3938  Emma Khan, Isabella Davies, Chloe Bakshi, Aiko...
# 3361  Amara Johnson, Maria Park, Sophie Petrov, Meer...
# 5274  Liam Weber, Bikash Rossi, Aiko Ali, Marcus Has...
#
#                           country          date_added  release_year rating  \
# 4921                United States   December 22, 2018          1925  TV-MA
# 6879  South Africa, United States     January 3, 2014          1925  TV-MA
# 3938                        Japan  September 24, 2019          1926  TV-PG
# 3361                          NaN     August 23, 2021          1926  TV-Y7
# 5274                        India       July 13, 2017          1926  TV-MA
#
#      duration                 listed_in  \
# 4921   96 min       Cult Movies, Dramas
# 6879   50 min  Thrillers, Sports Movies
# 3938   51 min       Cult Movies, Dramas
# 3361  100 min            Crime TV Shows
# 5274  196 min                    Dramas
#
#                                             description
# 4921  Determined to start over, a teenage prodigy se...
# 6879  During a nationwide blackout, a rookie police ...
# 3938  Haunted by the past, a small-town teacher must...
# 3361  Torn between duty and desire, a group of colle...
# 5274  Haunted by the past, an ambitious chef builds ...

# %% [markdown]
# #### Q68. Show the 5 newest TV Shows.

# %% [markdown]
# #### Q69. Sort by `country` and put the missing values **first** (hint: `na_position="first"`).

# %%
# Your answer here

# %% [markdown]
# #### Q70. What does `ascending=[False, True]` mean when sorting by two columns? Demonstrate with `release_year` and `title` and explain in a comment.

# %%
# Your answer here

# %% [markdown]
# ## Section E — Updating Data (Q71–Q85)

# %% [markdown]
# #### Q71. Rename the column `listed_in` to `genres` (keep this change).

# %%
# Your answer here

# %% [markdown]
# #### Q72. Create a new column `age_years` = 2026 minus `release_year`.

# %%
# Your answer here

# %% [markdown]
# #### Q73. Create a column `is_movie` that is `True` when `type` is `"Movie"`.

# %%
# Your answer here

# %% [markdown]
# #### Q74. Create a column `is_recent` that is `True` when `release_year >= 2020`.

# %%
# Your answer here

# %% [markdown]
# #### Q75. Using `.loc` with a condition, set `rating` to `"UNRATED"` for all rows where `rating` is missing.

# %%
# Your answer here

# %% [markdown]
# #### Q76. Replace the value `"United States"` with `"USA"` in the `country` column (hint: `replace`).

# %%
# Your answer here

# %% [markdown]
# #### Q77. Convert all titles to UPPERCASE into a new column `title_upper` (hint: `str.upper`).

# %%
# Your answer here

# %% [markdown]
# #### Q78. Create a column `title_length` = number of characters in each title (hint: `str.len`).

# %%
# Your answer here

# %% [markdown]
# #### Q79. Using `.loc`, change the `title` of the row with index label 0 to `"My Favourite Show"`. Display that row to confirm.

# %%
# Your answer here

# %% [markdown]
# #### Q80. Add a column `platform` where every row has the value `"Netflix"`.

# %%
# Your answer here

# %% [markdown]
# #### Q81. Delete the column `title_upper` using `drop`.

# %%
# Your answer here

# %% [markdown]
# #### Q82. Change `release_year` to type `int32` using `astype`. Check with `dtypes`.

# %%
# Your answer here

# %% [markdown]
# #### Q83. Using `.loc` with a condition, create/overwrite a column `era` = `"old"` for titles before 2010 and `"new"` for 2010 onward (two `.loc` assignments, or `np.where`).

# %%
# Your answer here

# %% [markdown]
# #### Q84. Increase `age_years` by 1 for **all** rows in one operation.

# %%
# Your answer here

# %% [markdown]
# #### Q85. Explain in a markdown comment: why is `df.loc[condition, "col"] = value` the SAFE way to update, instead of `df[condition]["col"] = value`? (SettingWithCopyWarning!)

# %%
# Your answer here

# %% [markdown]
# ## Section F — GroupBy (Q86–Q105)

# %% [markdown]
# #### Q86. Group by `type` and count the number of titles in each group (`size()`).

# %%
# Your answer here

# %% [markdown]
# #### Q87. Group by `rating` and count titles. Which rating is most common?

# %%
# Your answer here

# %% [markdown]
# #### Q88. Group by `release_year` and count titles. Which year had the most releases?

# %%
# Your answer here

# %% [markdown]
# #### Q89. Group by `type` and find the **minimum** and **maximum** `release_year` for each (hint: `agg(["min","max"])`).

# %%
# Your answer here

# %% [markdown]
# #### Q90. Group by `type` and compute the **average** `age_years`.

# %%
# Your answer here

# %% [markdown]
# #### Q91. Group by `country` and count titles — show only the top 10 (sort + head).

# %%
# Your answer here

# %% [markdown]
# #### Q92. Group by `rating` and compute the average `title_length`.

# %%
# Your answer here

# %% [markdown]
# #### Q93. Group by `era` (from Q83) and count Movies vs TV Shows (hint: group by TWO columns).

# %%
# Your answer here

# %% [markdown]
# #### Q94. Group by `type` and `rating` together and count. Display the result with `unstack()`.

# %%
# Your answer here

# %% [markdown]
# #### Q95. For Movies only: group by `release_year` and count — how many movies came out each year since 2015? (filter first, then group, then `.tail()`)

# %%
# Your answer here

# %% [markdown]
# #### Q96. Group by `country` and compute the average `release_year` — which 5 countries have the 'newest' catalogs on average? (sort descending, head)

# %%
# Your answer here

# %% [markdown]
# #### Q97. Use `value_counts()` on `genres` — why does this NOT give clean genre counts? Explain in a comment (hint: multiple genres in one cell).

# %%
# Your answer here

# %% [markdown]
# #### Q98. Group by `is_recent` and count — how many recent vs old titles?

# %%
# Your answer here

# %% [markdown]
# #### Q99. Group by `type` and use `.agg()` with a dictionary: count of `title` and mean of `age_years` in ONE command.

# %%
# Your answer here

# %% [markdown]
# #### Q100. Group by `rating` and show the **number of unique countries** per rating (hint: `nunique`).

# %%
# Your answer here

# %% [markdown]
# #### Q101. Using `groupby` + `head(1)`, show the FIRST title (by current order) in each `type` group.

# %%
# Your answer here

# %% [markdown]
# #### Q102. Group by `release_year` and count, then plot it with `.plot()` (line chart). What trend do you see?

# %%
# Your answer here

# %% [markdown]
# #### Q103. Group by `year_added`-style logic isn't possible yet — `date_added` is still text! Group by the **first 4 characters trick is wrong**. Explain in a comment why we need Section G (Cleaning) before we can group by the year a title was ADDED.

# %%
# Your answer here

# %% [markdown]
# #### Q104. Group by `type` and compute the **median** `release_year`.

# %%
# Your answer here

# %% [markdown]
# #### Q105. Challenge: for each `rating`, what percentage of titles are Movies? (hint: group by rating, compute the mean of `is_movie`, multiply by 100)

# %%
# Your answer here

# %% [markdown]
# ## Section G — Cleaning (Q106–Q125)

# %% [markdown]
# #### Q106. Re-check missing values per column (things changed since Section A!).

# %%
# Your answer here

# %% [markdown]
# #### Q107. Fill missing `director` values with `"Unknown"`.

# %%
# Your answer here

# %% [markdown]
# #### Q108. Fill missing `cast` values with `"Unknown"`.

# %%
# Your answer here

# %% [markdown]
# #### Q109. Fill missing `country` values with the **most common** country (hint: `mode()[0]`).

# %%
# Your answer here

# %% [markdown]
# #### Q110. Count the rows where `date_added` is missing, then drop those rows.

# %%
# Your answer here

# %% [markdown]
# #### Q111. `date_added` has extra spaces in some rows — strip them (hint: `str.strip`).

# %%
# Your answer here

# %% [markdown]
# #### Q112. Convert `date_added` to datetime with `pd.to_datetime`. Check the dtype after.

# %%
# Your answer here

# %% [markdown]
# #### Q113. NOW create `year_added` = `.dt.year` and `month_added` = `.dt.month_name()`.

# %%
# Your answer here

# %% [markdown]
# #### Q114. Group by `year_added` and count — which year did Netflix add the most content? (This is the question F103 could not answer!)

# %%
# Your answer here

# %% [markdown]
# #### Q115. Group by `month_added` and count — which month is most popular for adding content?

# %%
# Your answer here

# %% [markdown]
# #### Q116. Look at the `duration` column with `unique()` (first 20 values) — what TWO different formats do you see?

# %%
# Your answer here

# %% [markdown]
# #### Q117. Extract the number from `duration` into a new column `duration_int` (hint: `str.extract(r"(\\d+)")` then `astype(float)`).

# %%
# Your answer here

# %% [markdown]
# #### Q118. For Movies only: what is the average, minimum, and maximum duration in minutes?

# %%
# Your answer here

# %% [markdown]
# #### Q119. For TV Shows only: how many have more than 5 seasons? Show their titles.

# %%
# Your answer here

# %% [markdown]
# #### Q120. Check duplicated **titles** (not full rows): are there any titles that appear more than once? Display them.

# %%
# Your answer here

# %% [markdown]
# #### Q121. Are those duplicated titles real duplicates or different shows? Inspect a few with `.loc` and explain in a comment.

# %%
# Your answer here

# %% [markdown]
# #### Q122. The `rating` column contains some WRONG values that are actually durations (like `"74 min"`) — find them (hint: `str.contains("min", na=False)`).

# %%
# Your answer here

# %% [markdown]
# #### Q123. Fix those wrong rating rows: set their `rating` to `"UNRATED"` using `.loc`.

# %%
# Your answer here

# %% [markdown]
# #### Q124. Final check: run `info()` and `isna().sum()` — is the dataset clean now? Summarize what you fixed in a comment.

# %%
# Your answer here

# %% [markdown]
# #### Q125. Save your cleaned DataFrame to a new file `netflix_clean.csv` (without the index). This file is your submission proof!

# %%
# Your answer here

# %% [markdown]
# ---
# ## Submission
# - Answer **all 125 questions** — partial answers get partial marks
# - Run All must work top to bottom without errors (−5 marks if it crashes)
# - Submit BOTH files: `YourName_workbook.ipynb` and `netflix_clean.csv`
